# %% [markdown]
# <center>
# <img src="../../img/ods_stickers.jpg">
# ## Открытый курс по машинному обучению. Сессия № 2
# </center>
# Автор материала: программист-исследователь Mail.ru Group, старший преподаватель Факультета Компьютерных Наук ВШЭ Юрий Кашницкий. Материал распространяется на условиях лицензии [Creative Commons CC BY-NC-SA 4.0](https://creativecommons.org/licenses/by-nc-sa/4.0/). Можно использовать в любых целях (редактировать, поправлять и брать за основу), кроме коммерческих, но с обязательным упоминанием автора материала.

# %% [markdown]
# # <center>Тема 2. Визуальный анализ данных
# ## <center>Практическое задание. Визуальный анализ данных по пассажирам "Титаника". Решение

# %% [markdown]
# **<a href="https://www.kaggle.com/c/titanic">Соревнование</a> Kaggle "Titanic: Machine Learning from Disaster".**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# **Считываем обучающую выборку.**

# %%
train_df = pd.read_csv("../../data/titanic_train.csv", 
                       index_col='PassengerId')

# %%
train_df.head(2)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
#
#              SibSp  Parch     Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0  A/5 21171   7.2500   NaN        S
# 2                1      0   PC 17599  71.2833   C85        C

# %%
train_df.describe(include='all')
# Out:
#           Survived      Pclass                             Name   Sex  \
# count   891.000000  891.000000                              891   891
# unique         NaN         NaN                              891     2
# top            NaN         NaN  Hagland, Mr. Ingvald Olai Olsen  male
# freq           NaN         NaN                                1   577
# mean      0.383838    2.308642                              NaN   NaN
# std       0.486592    0.836071                              NaN   NaN
# min       0.000000    1.000000                              NaN   NaN
# 25%       0.000000    2.000000                              NaN   NaN
# 50%       0.000000    3.000000                              NaN   NaN
# 75%       1.000000    3.000000                              NaN   NaN
# max       1.000000    3.000000                              NaN   NaN
#
#                Age       SibSp       Parch Ticket        Fare        Cabin  \
# count   714.000000  891.000000  891.000000    891  891.000000          204
# unique         NaN         NaN         NaN    681         NaN          147
# top            NaN         NaN         NaN   1601         NaN  C23 C25 C27
# freq           NaN         NaN         NaN      7         NaN            4
# mean     29.699118    0.523008    0.381594    NaN   32.204208          NaN
# std      14.526497    1.102743    0.806057    NaN   49.693429          NaN
# min       0.420000    0.000000    0.000000    NaN    0.000000          NaN
# 25%      20.125000    0.000000    0.000000    NaN    7.910400          NaN
# 50%      28.000000    0.000000    0.000000    NaN   14.454200          NaN
# 75%      38.000000    1.000000    0.000000    NaN   31.000000          NaN
# max      80.000000    8.000000    6.000000    NaN  512.329200          NaN
#
#        Embarked
# count       889
# unique        3
# top           S
# freq        644
# mean        NaN
# std         NaN
# min         NaN
# 25%         NaN
# 50%         NaN
# 75%         NaN
# max         NaN

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
# Survived    891 non-null int64
# Pclass      891 non-null int64
# Name        891 non-null object
# Sex         891 non-null object
# Age         714 non-null float64
# SibSp       891 non-null int64
# Parch       891 non-null int64
# Ticket      891 non-null object
# Fare        891 non-null float64
# Cabin       204 non-null object
# Embarked    889 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %% [markdown]
# **Выкинем признак `Cabin`, а потом – все строки, где есть пропуски.**

# %%
train_df = train_df.drop('Cabin', axis=1).dropna()

# %% [markdown]
# **Постройте попарные зависимости признаков `Age`, `Fare`, `Pclass`, `Sex`, `SibSp`, `Parch`, `Embarked` и `Survived`. (метод `scatter_matrix ` Pandas или `pairplot` Seaborn).**

# %%
sns.pairplot(train_df[['Age', 'Fare', 'Pclass', 'Sex', 'SibSp', 'Parch', 'Embarked', 'Survived']])

# %% [markdown]
# **Как плата за билет (`Fare`) зависит от класса каюты (`Pclass`)? Постройте boxplot.**

# %%
sns.boxplot(x=train_df['Pclass'], y=train_df['Fare'])

# %% [markdown]
# **Такой boxplot получается не очень красивым из-за выбросов.**
#
# **Опционально: создайте признак `Fare_no_out` (стоимости без выбросов), в котором исключаются стоимости, отличающиеся от средней по классу более чем на 2 стандартных отклонения. Важно: надо исключать выбросы именно в зависимости от класса каюты. Иначе исключаться будут только самые большие (1 класс) и малые (3 класс) стоимости.**

# %%
train_df['Fare_no_out'] = train_df['Fare']
fare_pclass1 = train_df[train_df['Pclass'] == 1]['Fare']
fare_pclass2 = train_df[train_df['Pclass'] == 2]['Fare']
fare_pclass3 = train_df[train_df['Pclass'] == 3]['Fare']
fare_pclass1_no_out = [x for x in fare_pclass1 if abs(x - np.mean(fare_pclass1)) <= 2*np.std(fare_pclass1)]
fare_pclass2_no_out = [x for x in fare_pclass2 if abs(x - np.mean(fare_pclass2)) <= 2*np.std(fare_pclass2)]
fare_pclass3_no_out = [x for x in fare_pclass3 if abs(x - np.mean(fare_pclass3)) <= 2*np.std(fare_pclass3)]
a = fare_pclass1_no_out.append(fare_pclass2_no_out)
a = a.append(fare_pclass3_no_out)
train_df['Fare_no_out'] = a
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-c8ac74badfc5> in <module>
#       7 fare_pclass3_no_out = [x for x in fare_pclass3 if abs(x - np.mean(fare_pclass3)) <= 2*np.std(fare_pclass3)]
#       8 a = fare_pclass1_no_out.append(fare_pclass2_no_out)
# ----> 9 a = a.append(fare_pclass3_no_out)
#      10 train_df['Fare_no_out'] = a
#
# AttributeError: 'NoneType' object has no attribute 'append'

# %% [markdown]
# **Каково соотношение погибших и выживших в зависимости от пола? Отобразите c помощью Seaborn.countplot c аргументом hue.**

# %%
# Ваш код здесь
sns.countplot(x='Survived', hue='Sex', data=train_df)

# %% [markdown]
# **Каково соотношение погибших и выживших в зависимости от класса каюты? Отобразите c помощью Seaborn.countplot c аргументом hue.**

# %%
# Ваш код здесь
sns.countplot(x='Survived', hue='Pclass', data=train_df)

# %% [markdown]
# **Как факт выживания зависит от возраста пассажира? Проверьте (графически) предположение, что молодые чаще выживали. Пусть, условно, молодые - младше 30 лет, пожилые – старше 60 лет.**

# %%
# Ваш код здесь
sns.countplot(x='Survived', hue='Age', data=train_df)
